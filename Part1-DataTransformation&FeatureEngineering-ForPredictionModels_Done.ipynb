# %% [markdown]
# ## Importing all the Data Files

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### User Transactions Data

# %%
transactions = pd.read_csv('Dataset/transactions_v2.csv')

# %%
transactions.head()
# Out:
#                                            msno  payment_method_id  \
# 0  ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=                 32
# 1  ++lvGPJOinuin/8esghpnqdljm6NXS8m8Zwchc7gOeA=                 41
# 2  +/GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc=                 36
# 3  +/w1UrZwyka4C9oNH3+Q8fUf3fD8R3EwWrx57ODIsqk=                 36
# 4  +00PGzKTYqtnb65mPKPyeHXcZEwqiEzktpQksaaSC3c=                 41
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 90              298                 298              0
# 1                 30              149                 149              1
# 2                 30              180                 180              1
# 3                 30              180                 180              1
# 4                 30               99                  99              1
#
#    transaction_date  membership_expire_date  is_cancel
# 0          20170131                20170504          0
# 1          20150809                20190412          0
# 2          20170303                20170422          0
# 3          20170329                20170331          1
# 4          20170323                20170423          0

# %%
transactions.shape
# Out:
# (1431009, 9)

# %%
transactions['msno'].unique().shape
# Out:
# (1197050,)

# %% [markdown]
# ### User Churn Data

# %%
train = pd.read_csv('Dataset/train_v2.csv')

# %%
train.shape
# Out:
# (970960, 2)

# %%
train.head()
# Out:
#                                            msno  is_churn
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1

# %%
train['is_churn'].value_counts()
# Out:
# 0    883630
# 1     87330
# Name: is_churn, dtype: int64

# %%
from  sklearn.model_selection  import  train_test_split 
X = train.drop('is_churn',axis=1)
y= train['is_churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0,stratify=y)

# %%
y_test.value_counts()
# Out:
# 0    88363
# 1     8733
# Name: is_churn, dtype: int64

# %%
train = X_test

# %%
train['is_churn']=y_test

# %%
train
# Out:
#                                                 msno  is_churn
# 659299  PR5OUJD4mPxUtFbxFafhbsfEFtx3yyLJvILMFdAQBDY=         0
# 159297  zcWIOjtZewyhPBiEBH/Y14cJHf6Z0pVtHmNxE5RdTWg=         0
# 116089  OH1thT0rHD9tuOTZpjTf+/V9u+PTLLByBZgLlDKTuxI=         0
# 79017   ZI0vEMRlsRYpIAfpN5hxfQ5iI7ildveQ/YE0LeXHWOs=         0
# 342223  UJ7jSk2WwdGroS+c9BjalClWG8eoi3QluastOanZLCQ=         0
# ...                                              ...       ...
# 16015   pJGX4+E0QBsEjd7F4saUgIo4AHEyubK4ioyjNehzVBA=         1
# 160     04Mn5oun4VJEKGLCfYpCThMsAK7rgr6vqdaVHjWIc3o=         1
# 486427  efyRqPeug9RsS3D7KnUpHLj5Fb2XZppycF1PEn0t2I0=         0
# 251314  94ML690IJssyphxrJx9aoSt8l+jR7vmutbWzMqk04SY=         0
# 164704  HxGeiy7DX47GMXShp2B7pimP05fDH1Ga/RkRc6ufsZE=         0
#
# [97096 rows x 2 columns]

# %%
train.shape
# Out:
# (97096, 2)

# %%
train['is_churn'].value_counts()
# Out:
# 0    88363
# 1     8733
# Name: is_churn, dtype: int64

# %% [markdown]
# ### User Logs Data

# %%
logs = pd.read_csv('Dataset/user_logs_v2.csv')

# %%
logs.shape
# Out:
# (18396362, 9)

# %% [markdown]
# ### Merging User Churn and User Transactions Data

# %%
from sklearn.preprocessing import LabelEncoder #encoder package of sklearn
le = LabelEncoder() #le variable has been assigned a labelencoder function

transactions['msno'] = le.fit_transform(transactions['msno'].astype(str))
train['msno'] = le.fit_transform(train['msno'].astype(str))
logs['msno'] = le.fit_transform(logs['msno'].astype(str))

# %%
trial_join = pd.merge(train, transactions, on='msno', how='inner')

# %%
trial_join.shape
# Out:
# (115391, 10)

# %%
len(trial_join['msno'].unique())
# Out:
# 97096

# %% [markdown]
# trial_join.to_csv('transformed_user_summary_ltv.csv',index=False)

# %% [markdown]
# ### Merging User Churn and User Logs Data

# %%
logs_join = pd.merge(train, logs, on='msno', how='inner')

# %%
logs_join
# Out:
#           msno  is_churn      date  num_25  num_50  num_75  num_985  num_100  \
# 0        41633         0  20170319       0       0       0        0      105
# 1        41633         0  20170314      22      22       5        5        9
# 2        41633         0  20170320      13       1       0        5       68
# 3        41633         0  20170326      17       1       0        3       16
# 4        41633         0  20170328       8       1       0        1       23
# ...        ...       ...       ...     ...     ...     ...      ...      ...
# 1620180  16742         0  20170313       1       0       0        0       21
# 1620181  16742         0  20170327       2       0       1        1        4
# 1620182  16742         0  20170308       2       0       1        2       20
# 1620183  16742         0  20170312       7       1       2        1       15
# 1620184  30205         0  20170318       1       0       0        1       83
#
#          num_unq  total_secs
# 0             32   26355.191
# 1             55    5849.439
# 2             44   18241.627
# 3             23    4947.604
# 4             18    6405.278
# ...          ...         ...
# 1620180       20    7293.067
# 1620181        7    1172.677
# 1620182       23    9140.741
# 1620183       19    6975.761
# 1620184       84   20083.097
#
# [1620185 rows x 10 columns]

# %%
len(logs_join['msno'].unique())
# Out:
# 97096

# %% [markdown]
# ## Creating a new Dataframe with Summarized Information of each User

# %%
df = trial_join

# %%
from datetime import datetime, date

# %%
df['transaction_date'] = df['transaction_date'].astype(str)

# %%
df['day'] = df['transaction_date'].str.slice(6,8,1)
df['month'] = df['transaction_date'].str.slice(4,6,1)
df['year'] = df['transaction_date'].str.slice(0,4,1)
df['trans_date'] = pd.to_datetime(df[['day', 'month', 'year']])

# %%
df=df.drop(['day','year','month'],axis=1)

# %%
import datetime as dft
df_6m = df[(df.trans_date >= dft.datetime(2017,1,1)) & (df.trans_date < dft.datetime(2017,3,31))].reset_index(drop=True)

# %%
df_6m.shape
# Out:
# (84076, 11)

# %%
df_3m = df[(df.trans_date >= dft.datetime(2016,7,1)) & (df.trans_date < dft.datetime(2016,12,31))].reset_index(drop=True)

# %%
df_3m.shape
# Out:
# (6791, 11)

# %% [markdown]
# ### Creating Monetary Column

# %%
df_6m

# %%
just_revenue = df.groupby("msno")["actual_amount_paid"].sum()

# %%
just_revenue.unique()
# Out:
# array([1599,   99,  298,  149, 1788,  894,  129,  180,  100,  198, 2988,
#         150,  536, 2400, 1380,  258,  480,  398,  477, 5511, 3326,  699,
#        1200, 1937, 1299,  119,  360,    0,  447,  685, 2831,  930,  300,
#         397, 2235,  495,  745, 1043, 3930,  799,  540,  387,  199, 3138,
#         600, 2931,  645, 2384,  596,  297, 1860, 1490,  929, 1399, 1485,
#         248,  594, 2549, 1072,  329,  834, 1693, 2499, 1639, 1341,  278,
#         725, 4188,  358, 3576,  229, 1000,  500, 3078, 1192,  134, 1985,
#        1984,  720, 4895,  585,  427,  200, 2595,  299, 1887, 5165, 1470,
#        2859, 2265,  249, 2493, 1023, 2598,  228, 1487, 2334, 2631, 2036,
#         629,  450,  954,  279, 6057,  396,  848,  665, 1500,  595, 1112,
#        2999,  847, 1260,  357, 2682,  327, 3951, 1142,  874,  478,  378,
#        2980, 4865, 3129,  695,  546,  792, 3387,  347, 2323, 1638, 1254,
#         844, 1908, 1619,  496, 1431, 4141,  993,  547, 2847,  120,  517,
#        5243, 2000, 1448, 2484, 1897, 2086, 2088,  626,  933, 3784, 1986,
#         576, 3079, 1047, 1022,  400, 1935,  660, 4650, 3278,  330, 2313,
#        1589, 1371,   35,  774, 3198, 4508, 1350, 1390, 1281, 3515, 4470,
#        4547,  509,  814, 1251, 1748, 1113,  924,  309, 5452, 1966, 1539,
#        2508,  854, 1498, 3068, 2483, 2880, 3048, 5314, 2481, 2621, 3087,
#         449,  399, 3366, 1708, 2718, 3813, 4468,  749, 1410, 1089,  983,
#        2642,  923,  516, 3897,  785,  131, 1968,  777, 1181, 4021, 3277,
#         947,  655, 3365, 1386, 4386, 1290,  990, 1082, 2324, 1866,  696,
#        1032, 1349,  957, 1211, 3217, 1092, 4706, 3862,  963, 5364,  476,
#         780, 2164, 1946,  997, 2444, 2286, 2790,  734, 1608, 3694,  407,
#         776, 1419, 1430,  240, 3912, 1300, 1370, 1738,  627,  597, 1987,
#        1588,  555, 1824, 2115, 1042, 1648, 3098, 1141,  426, 6793, 3713,
#        1291, 1140,  992, 1074, 3725, 2800,  804, 3543, 4325, 3294, 2700,
#         775, 2671,  498, 1749, 2533, 1041, 3962,  903, 2064, 1856,  693,
#        2688, 4112, 2989,  952, 1261,  446, 1191, 1746, 3892, 1905, 2862,
#        2580, 3207,  507, 1519, 2185, 2877, 2186,  934, 1728, 1100,  105,
#        3109, 5094, 1917,  948,  587, 1549, 5363, 3733, 4439, 1440, 4081,
#        1377, 5689,  556, 1172,  794, 3177,  328,  658, 1488,  377, 5513,
#         900, 2781, 5066, 1188, 2799, 1926,  181, 2651, 1688,    1, 1598,
#        1800,  943, 5685, 3227, 1797, 4887,  657, 1076, 1779, 1837, 1389,
#        1777,  676,  184, 2500, 2046, 1194, 2622, 8850,  625, 2373, 3288,
#        1150, 2919, 2204, 1614, 1637,  580, 3843,  716, 3783, 5332, 2780,
#        2026, 1152,  778,  843, 1080, 2094, 1687, 4250, 4374,  456],
#       dtype=int64)

# %%
just_revenue
# Out:
# msno
# 0        1599
# 1          99
# 2         298
# 3         149
# 4         149
#          ...
# 97091     149
# 97092      99
# 97093      99
# 97094     298
# 97095     149
# Name: actual_amount_paid, Length: 97096, dtype: int64

# %% [markdown]
# ### Creating Frequency Column

# %%
just_count_subs = df.groupby("msno")["payment_plan_days"].sum()

# %%
just_count_subs
# Out:
# msno
# 0        395
# 1         30
# 2         60
# 3         30
# 4         30
#         ...
# 97091     30
# 97092     30
# 97093     30
# 97094     60
# 97095     30
# Name: payment_plan_days, Length: 97096, dtype: int64

# %% [markdown]
# ### Creating Recency Column

# %%
import datetime as dft
a = dft.datetime(2017,4,1)

# %%
df['Days_Diff'] = ( a - df['trans_date']).dt.days

# %%
df['trans_date'].max()
# Out:
# Timestamp('2017-03-31 00:00:00')

# %%
df['trans_date'].min()
# Out:
# Timestamp('2015-01-01 00:00:00')

# %% [markdown]
# ### Creating a new User RFM DataFrame and adding 3 columns - Recency, Frequency and Monetary

# %%
just_recency = df.groupby("msno")["Days_Diff"].min()

# %%
user_rfm_1 = pd.merge(just_revenue, just_recency, on='msno', how='inner')

# %%
user_rfm = pd.merge(user_rfm_1, just_count_subs, on='msno', how='inner')

# %%
user_rfm.rename(columns = {'actual_amount_paid':'Monetary', 'Days_Diff':'Recency','payment_plan_days':'Frequency'}, inplace = True)

# %%
user_rfm
# Out:
#        Monetary  Recency  Frequency
# msno
# 0          1599      160        395
# 1            99       17         30
# 2           298        1         60
# 3           149        6         30
# 4           149       17         30
# ...         ...      ...        ...
# 97091       149        1         30
# 97092        99       28         30
# 97093        99       22         30
# 97094       298        1         60
# 97095       149       22         30
#
# [97096 rows x 3 columns]

# %% [markdown]
# ### Creating is_autoRenew column

# %%
auto_renew = df.groupby("msno")["is_auto_renew"].max()

# %%
auto_renew.value_counts()
# Out:
# 1    75030
# 0    22066
# Name: is_auto_renew, dtype: int64

# %%
user_summary = pd.merge(user_rfm, auto_renew, on='msno', how='inner')

# %%
user_summary
# Out:
#        Monetary  Recency  Frequency  is_auto_renew
# msno
# 0          1599      160        395              0
# 1            99       17         30              1
# 2           298        1         60              1
# 3           149        6         30              1
# 4           149       17         30              1
# ...         ...      ...        ...            ...
# 97091       149        1         30              1
# 97092        99       28         30              1
# 97093        99       22         30              1
# 97094       298        1         60              1
# 97095       149       22         30              1
#
# [97096 rows x 4 columns]

# %% [markdown]
# ### Creating is_discount column

# %%
df['discount']=df['plan_list_price']-df['actual_amount_paid']

# %%
is_dis = df.groupby("msno")["discount"].sum()

# %%
user_summary = pd.merge(user_summary, is_dis, on='msno', how='inner')

# %%
user_summary
# Out:
#        Monetary  Recency  Frequency  is_auto_renew  discount
# msno
# 0          1599      160        395              0         0
# 1            99       17         30              1         0
# 2           298        1         60              1         0
# 3           149        6         30              1         0
# 4           149       17         30              1         0
# ...         ...      ...        ...            ...       ...
# 97091       149        1         30              1         0
# 97092        99       28         30              1         0
# 97093        99       22         30              1         0
# 97094       298        1         60              1         0
# 97095       149       22         30              1         0
#
# [97096 rows x 5 columns]

# %%
user_summary['is_discount'] = 0
user_summary.loc[user_summary['discount']>0,'is_discount'] = 1

# %%
user_summary.drop(['discount'], axis=1)
# Out:
#        Monetary  Recency  Frequency  is_auto_renew  is_discount
# msno
# 0          1599      160        395              0            0
# 1            99       17         30              1            0
# 2           298        1         60              1            0
# 3           149        6         30              1            0
# 4           149       17         30              1            0
# ...         ...      ...        ...            ...          ...
# 97091       149        1         30              1            0
# 97092        99       28         30              1            0
# 97093        99       22         30              1            0
# 97094       298        1         60              1            0
# 97095       149       22         30              1            0
#
# [97096 rows x 5 columns]

# %%
user_summary
# Out:
#        Monetary  Recency  Frequency  is_auto_renew  discount  is_discount
# msno
# 0          1599      160        395              0         0            0
# 1            99       17         30              1         0            0
# 2           298        1         60              1         0            0
# 3           149        6         30              1         0            0
# 4           149       17         30              1         0            0
# ...         ...      ...        ...            ...       ...          ...
# 97091       149        1         30              1         0            0
# 97092        99       28         30              1         0            0
# 97093        99       22         30              1         0            0
# 97094       298        1         60              1         0            0
# 97095       149       22         30              1         0            0
#
# [97096 rows x 6 columns]

# %% [markdown]
# ### Creating Preffered Plan Column

# %%
best_plan = df.groupby("msno")["payment_plan_days"].agg(lambda x:x.value_counts().index[0])

# %%
best_plan.value_counts()
# Out:
# 30     82032
# 410     6457
# 195     2181
# 180     1782
# 90      1306
# 395      812
# 7        360
# 100      344
# 415      282
# 365      272
# 200      238
# 360      209
# 120      186
# 240      139
# 60       136
# 450      135
# 400      126
# 270       60
# 1         25
# 10         6
# 14         4
# 80         2
# 0          1
# 45         1
# Name: payment_plan_days, dtype: int64

# %%
user_summary = pd.merge(user_summary, best_plan, on='msno', how='inner')

# %%
user_summary.rename(columns={'payment_plan_days':'BestPlan'}, inplace = True)

# %%
user_summary = user_summary.drop(['discount'], axis=1)

# %%
user_summary
# Out:
#        Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan
# msno
# 0          1599      160        395              0            0       395
# 1            99       17         30              1            0        30
# 2           298        1         60              1            0        30
# 3           149        6         30              1            0        30
# 4           149       17         30              1            0        30
# ...         ...      ...        ...            ...          ...       ...
# 97091       149        1         30              1            0        30
# 97092        99       28         30              1            0        30
# 97093        99       22         30              1            0        30
# 97094       298        1         60              1            0        30
# 97095       149       22         30              1            0        30
#
# [97096 rows x 6 columns]

# %% [markdown]
# ### Creating Total Active Days Per Month Column

# %%
df2 = logs_join

# %%
total_active_days_per_month = df2.groupby("msno")["total_secs"].count()

# %%
total_active_days_per_month.value_counts()
# Out:
# 1     7656
# 31    7422
# 30    5084
# 2     4263
# 29    4220
# 28    3865
# 27    3540
# 3     3505
# 4     3356
# 26    3287
# 25    3055
# 24    2896
# 23    2763
# 5     2697
# 22    2681
# 21    2578
# 19    2544
# 20    2535
# 18    2367
# 17    2329
# 15    2274
# 9     2270
# 6     2267
# 7     2244
# 8     2226
# 13    2224
# 14    2217
# 12    2214
# 11    2210
# 16    2166
# 10    2141
# Name: total_secs, dtype: int64

# %%
user_summary = pd.merge(user_summary, total_active_days_per_month, on='msno', how='inner')

# %%
user_summary.rename(columns={'total_secs':'active_days_per_month'}, inplace = True)

# %%
user_summary
# Out:
#        Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# msno
# 0          1599      160        395              0            0       395
# 1            99       17         30              1            0        30
# 2           298        1         60              1            0        30
# 3           149        6         30              1            0        30
# 4           149       17         30              1            0        30
# ...         ...      ...        ...            ...          ...       ...
# 97091       149        1         30              1            0        30
# 97092        99       28         30              1            0        30
# 97093        99       22         30              1            0        30
# 97094       298        1         60              1            0        30
# 97095       149       22         30              1            0        30
#
#        active_days_per_month
# msno
# 0                         26
# 1                         31
# 2                         28
# 3                         21
# 4                         29
# ...                      ...
# 97091                     10
# 97092                      1
# 97093                     12
# 97094                     20
# 97095                     30
#
# [97096 rows x 7 columns]

# %% [markdown]
# ### Creating Total_Usage_Time_Per_Month Column

# %%
total_usage_time_per_month = df2.groupby("msno")["total_secs"].sum()

# %%
total_usage_time_per_month
# Out:
# msno
# 0        117907.425
# 1        192527.892
# 2        115411.260
# 3        149896.558
# 4        116433.247
#             ...
# 97091     75487.962
# 97092       602.097
# 97093     51808.482
# 97094    162554.908
# 97095    344383.640
# Name: total_secs, Length: 97096, dtype: float64

# %%
user_summary = pd.merge(user_summary, total_usage_time_per_month, on='msno', how='inner')

# %%
user_summary.rename(columns={'total_secs':'total_usage_time_per_month'}, inplace = True)

# %%
user_summary
# Out:
#        Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# msno
# 0          1599      160        395              0            0       395
# 1            99       17         30              1            0        30
# 2           298        1         60              1            0        30
# 3           149        6         30              1            0        30
# 4           149       17         30              1            0        30
# ...         ...      ...        ...            ...          ...       ...
# 97091       149        1         30              1            0        30
# 97092        99       28         30              1            0        30
# 97093        99       22         30              1            0        30
# 97094       298        1         60              1            0        30
# 97095       149       22         30              1            0        30
#
#        active_days_per_month  total_usage_time_per_month
# msno
# 0                         26                  117907.425
# 1                         31                  192527.892
# 2                         28                  115411.260
# 3                         21                  149896.558
# 4                         29                  116433.247
# ...                      ...                         ...
# 97091                     10                   75487.962
# 97092                      1                     602.097
# 97093                     12                   51808.482
# 97094                     20                  162554.908
# 97095                     30                  344383.640
#
# [97096 rows x 8 columns]

# %% [markdown]
# ### Creating Total Unique Songs Played Per Month Column

# %%
total_unique_songs_played_per_month = df2.groupby("msno")["num_unq"].sum()

# %%
total_unique_songs_played_per_month
# Out:
# msno
# 0         530
# 1         885
# 2         468
# 3         828
# 4         230
#          ...
# 97091     356
# 97092       5
# 97093     123
# 97094     640
# 97095    1252
# Name: num_unq, Length: 97096, dtype: int64

# %%
user_summary = pd.merge(user_summary, total_unique_songs_played_per_month, on='msno', how='inner')

# %%
user_summary.rename(columns={'num_unq':'total_unique_songs_played_per_month'}, inplace = True)

# %%
user_summary
# Out:
#        Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# msno
# 0          1599      160        395              0            0       395
# 1            99       17         30              1            0        30
# 2           298        1         60              1            0        30
# 3           149        6         30              1            0        30
# 4           149       17         30              1            0        30
# ...         ...      ...        ...            ...          ...       ...
# 97091       149        1         30              1            0        30
# 97092        99       28         30              1            0        30
# 97093        99       22         30              1            0        30
# 97094       298        1         60              1            0        30
# 97095       149       22         30              1            0        30
#
#        active_days_per_month  total_usage_time_per_month  \
# msno
# 0                         26                  117907.425
# 1                         31                  192527.892
# 2                         28                  115411.260
# 3                         21                  149896.558
# 4                         29                  116433.247
# ...                      ...                         ...
# 97091                     10                   75487.962
# 97092                      1                     602.097
# 97093                     12                   51808.482
# 97094                     20                  162554.908
# 97095                     30                  344383.640
#
#        total_unique_songs_played_per_month
# msno
# 0                                      530
# 1                                      885
# 2                                      468
# 3                                      828
# 4                                      230
# ...                                    ...
# 97091                                  356
# 97092                                    5
# 97093                                  123
# 97094                                  640
# 97095                                 1252
#
# [97096 rows x 9 columns]

# %% [markdown]
# ### Creating Columns related to length of songs played

# %%
df2['percent_25'] = df2['num_25']/(df2['num_25']+df2['num_50']+df2['num_75']+df2['num_985']+df2['num_100'])
df2['percent_50'] = df2['num_50']/(df2['num_25']+df2['num_50']+df2['num_75']+df2['num_985']+df2['num_100'])
df2['percent_100'] = (df2['num_985']+df2['num_100'])/(df2['num_25']+df2['num_50']+df2['num_75']+df2['num_985']+df2['num_100'])

# %%
df2.head()
# Out:
#     msno  is_churn      date  num_25  num_50  num_75  num_985  num_100  \
# 0  41633         0  20170319       0       0       0        0      105
# 1  41633         0  20170314      22      22       5        5        9
# 2  41633         0  20170320      13       1       0        5       68
# 3  41633         0  20170326      17       1       0        3       16
# 4  41633         0  20170328       8       1       0        1       23
#
#    num_unq  total_secs  percent_25  percent_50  percent_100
# 0       32   26355.191    0.000000    0.000000     1.000000
# 1       55    5849.439    0.349206    0.349206     0.222222
# 2       44   18241.627    0.149425    0.011494     0.839080
# 3       23    4947.604    0.459459    0.027027     0.513514
# 4       18    6405.278    0.242424    0.030303     0.727273

# %%
Percent_Songs_Played_25 = df2.groupby("msno")["percent_25"].mean()*100
Percent_Songs_Played_50 = df2.groupby("msno")["percent_50"].mean()*100
Percent_Songs_Played_100 = df2.groupby("msno")["percent_100"].mean()*100

# %%
user_summary = pd.merge(user_summary, Percent_Songs_Played_25, on='msno', how='inner')
user_summary = pd.merge(user_summary, Percent_Songs_Played_50, on='msno', how='inner')
user_summary = pd.merge(user_summary, Percent_Songs_Played_100, on='msno', how='inner')

# %%
user_summary.rename(columns={'percent_25':'Percent_Songs_Played_25', 'percent_50':'Percent_Songs_Played_50', 'percent_100':'Percent_Songs_Played_100'}, inplace = True)

# %%
user_summary
# Out:
#        Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# msno
# 0          1599      160        395              0            0       395
# 1            99       17         30              1            0        30
# 2           298        1         60              1            0        30
# 3           149        6         30              1            0        30
# 4           149       17         30              1            0        30
# ...         ...      ...        ...            ...          ...       ...
# 97091       149        1         30              1            0        30
# 97092        99       28         30              1            0        30
# 97093        99       22         30              1            0        30
# 97094       298        1         60              1            0        30
# 97095       149       22         30              1            0        30
#
#        active_days_per_month  total_usage_time_per_month  \
# msno
# 0                         26                  117907.425
# 1                         31                  192527.892
# 2                         28                  115411.260
# 3                         21                  149896.558
# 4                         29                  116433.247
# ...                      ...                         ...
# 97091                     10                   75487.962
# 97092                      1                     602.097
# 97093                     12                   51808.482
# 97094                     20                  162554.908
# 97095                     30                  344383.640
#
#        total_unique_songs_played_per_month  Percent_Songs_Played_25  \
# msno
# 0                                      530                20.177022
# 1                                      885                17.864410
# 2                                      468                 7.021077
# 3                                      828                23.449066
# 4                                      230                14.380372
# ...                                    ...                      ...
# 97091                                  356                28.317247
# 97092                                    5                20.000000
# 97093                                  123                10.449385
# 97094                                  640                 6.277635
# 97095                                 1252                 5.850851
#
#        Percent_Songs_Played_50  Percent_Songs_Played_100
# msno
# 0                     3.482550                 74.636630
# 1                     8.453724                 67.017440
# 2                     3.338308                 87.340876
# 3                    12.609433                 54.993834
# 4                     3.943355                 77.144280
# ...                        ...                       ...
# 97091                 8.417237                 60.541827
# 97092                20.000000                 20.000000
# 97093                 4.037356                 83.239187
# 97094                 1.676004                 91.130939
# 97095                 1.955616                 90.290761
#
# [97096 rows x 12 columns]

# %%
user_summary.shape
# Out:
# (97096, 12)

# %%
user_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97096 entries, 0 to 97095
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Monetary                             97096 non-null  int64
#  1   Recency                              97096 non-null  int64
#  2   Frequency                            97096 non-null  int64
#  3   is_auto_renew                        97096 non-null  int64
#  4   is_discount                          97096 non-null  int64
#  5   BestPlan                             97096 non-null  int64
#  6   active_days_per_month                97096 non-null  int64
#  7   total_usage_time_per_month           97096 non-null  float64
#  8   total_unique_songs_played_per_month  97096 non-null  int64
#  9   Percent_Songs_Played_25              97096 non-null  float64
#  10  Percent_Songs_Played_50              97096 non-null  float64
#  11  Percent_Songs_Played_100             97096 non-null  float64
# dtypes: float64(4), int64(8)
# memory usage: 9.6 MB

# %% [markdown]
# ### Adding is_churn column

# %%
user_summary['is_churn'] = df2['is_churn']

# %%
user_summary
# Out:
#        Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# msno
# 0          1599      160        395              0            0       395
# 1            99       17         30              1            0        30
# 2           298        1         60              1            0        30
# 3           149        6         30              1            0        30
# 4           149       17         30              1            0        30
# ...         ...      ...        ...            ...          ...       ...
# 97091       149        1         30              1            0        30
# 97092        99       28         30              1            0        30
# 97093        99       22         30              1            0        30
# 97094       298        1         60              1            0        30
# 97095       149       22         30              1            0        30
#
#        active_days_per_month  total_usage_time_per_month  \
# msno
# 0                         26                  117907.425
# 1                         31                  192527.892
# 2                         28                  115411.260
# 3                         21                  149896.558
# 4                         29                  116433.247
# ...                      ...                         ...
# 97091                     10                   75487.962
# 97092                      1                     602.097
# 97093                     12                   51808.482
# 97094                     20                  162554.908
# 97095                     30                  344383.640
#
#        total_unique_songs_played_per_month  Percent_Songs_Played_25  \
# msno
# 0                                      530                20.177022
# 1                                      885                17.864410
# 2                                      468                 7.021077
# 3                                      828                23.449066
# 4                                      230                14.380372
# ...                                    ...                      ...
# 97091                                  356                28.317247
# 97092                                    5                20.000000
# 97093                                  123                10.449385
# 97094                                  640                 6.277635
# 97095                                 1252                 5.850851
#
#        Percent_Songs_Played_50  Percent_Songs_Played_100  is_churn
# msno
# 0                     3.482550                 74.636630         0
# 1                     8.453724                 67.017440         0
# 2                     3.338308                 87.340876         0
# 3                    12.609433                 54.993834         0
# 4                     3.943355                 77.144280         0
# ...                        ...                       ...       ...
# 97091                 8.417237                 60.541827         0
# 97092                20.000000                 20.000000         0
# 97093                 4.037356                 83.239187         0
# 97094                 1.676004                 91.130939         0
# 97095                 1.955616                 90.290761         0
#
# [97096 rows x 13 columns]

# %%
user_summary.reset_index(level=0, inplace=True)

# %%
user_summary
# Out:
#         msno  Monetary  Recency  Frequency  is_auto_renew  is_discount  \
# 0          0      1599      160        395              0            0
# 1          1        99       17         30              1            0
# 2          2       298        1         60              1            0
# 3          3       149        6         30              1            0
# 4          4       149       17         30              1            0
# ...      ...       ...      ...        ...            ...          ...
# 97091  97091       149        1         30              1            0
# 97092  97092        99       28         30              1            0
# 97093  97093        99       22         30              1            0
# 97094  97094       298        1         60              1            0
# 97095  97095       149       22         30              1            0
#
#        BestPlan  active_days_per_month  total_usage_time_per_month  \
# 0           395                     26                  117907.425
# 1            30                     31                  192527.892
# 2            30                     28                  115411.260
# 3            30                     21                  149896.558
# 4            30                     29                  116433.247
# ...         ...                    ...                         ...
# 97091        30                     10                   75487.962
# 97092        30                      1                     602.097
# 97093        30                     12                   51808.482
# 97094        30                     20                  162554.908
# 97095        30                     30                  344383.640
#
#        total_unique_songs_played_per_month  Percent_Songs_Played_25  \
# 0                                      530                20.177022
# 1                                      885                17.864410
# 2                                      468                 7.021077
# 3                                      828                23.449066
# 4                                      230                14.380372
# ...                                    ...                      ...
# 97091                                  356                28.317247
# 97092                                    5                20.000000
# 97093                                  123                10.449385
# 97094                                  640                 6.277635
# 97095                                 1252                 5.850851
#
#        Percent_Songs_Played_50  Percent_Songs_Played_100  is_churn
# 0                     3.482550                 74.636630         0
# 1                     8.453724                 67.017440         0
# 2                     3.338308                 87.340876         0
# 3                    12.609433                 54.993834         0
# 4                     3.943355                 77.144280         0
# ...                        ...                       ...       ...
# 97091                 8.417237                 60.541827         0
# 97092                20.000000                 20.000000         0
# 97093                 4.037356                 83.239187         0
# 97094                 1.676004                 91.130939         0
# 97095                 1.955616                 90.290761         0
#
# [97096 rows x 14 columns]

# %%
user_summary.shape
# Out:
# (97096, 14)

# %% [markdown]
# ## Exporting the Cleaned Dataset as CSV for next steps

# %%
# saving the dataframe to csv 
user_summary.to_csv('TransformedDataset/transformed_user_summary.csv',index=False)

# %%
# Read saved file and display  top 5 rows 
user_summary_file_saved = pd.read_csv('TransformedDataset/transformed_user_summary.csv')
user_summary_file_saved.head(n=5)
# Out:
#    msno  Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# 0     0      1599      160        395              0            0       395
# 1     1        99       17         30              1            0        30
# 2     2       298        1         60              1            0        30
# 3     3       149        6         30              1            0        30
# 4     4       149       17         30              1            0        30
#
#    active_days_per_month  total_usage_time_per_month  \
# 0                     26                  117907.425
# 1                     31                  192527.892
# 2                     28                  115411.260
# 3                     21                  149896.558
# 4                     29                  116433.247
#
#    total_unique_songs_played_per_month  Percent_Songs_Played_25  \
# 0                                  530                20.177022
# 1                                  885                17.864410
# 2                                  468                 7.021077
# 3                                  828                23.449066
# 4                                  230                14.380372
#
#    Percent_Songs_Played_50  Percent_Songs_Played_100  is_churn
# 0                 3.482550                 74.636630         0
# 1                 8.453724                 67.017440         0
# 2                 3.338308                 87.340876         0
# 3                12.609433                 54.993834         0
# 4                 3.943355                 77.144280         0

# %%
user_summary_file_saved.shape
# Out:
# (97096, 14)

# %% [markdown]
# # FOR LTV

# %%
user_summary_ltv = pd.merge(user_summary, df_6m, on='msno', how='inner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20132/2558496031.py in <module>
# ----> 1 user_summary_ltv = pd.merge(user_summary, df_6m, on='msno', how='inner')
#
# NameError: name 'df_6m' is not defined

# %%
user_summary_ltv.head()

# %%
revenue_6m = df_6m.groupby("msno")["actual_amount_paid"].sum()

# %%
revenue_6m.shape

# %%
user_summary_ltv = pd.merge(user_summary, revenue_6m, on='msno', how='inner')

# %%
user_summary_ltv.shape

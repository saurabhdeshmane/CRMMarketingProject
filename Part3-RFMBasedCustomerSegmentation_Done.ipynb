# %% [markdown]
# ## Importing the Transformed Data

# %%
# import libraries
from datetime import datetime, timedelta
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from __future__ import division

# %%
data = pd.read_csv('TransformedDataset/transformed_user_summary.csv')

# %%
data.head()
# Out:
#    msno  Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# 0     0      1599      160        395              0            0       395
# 1     1        99       17         30              1            0        30
# 2     2       298        1         60              1            0        30
# 3     3       149        6         30              1            0        30
# 4     4       149       17         30              1            0        30
#
#    active_days_per_month  total_usage_time_per_month  \
# 0                     26                  117907.425
# 1                     31                  192527.892
# 2                     28                  115411.260
# 3                     21                  149896.558
# 4                     29                  116433.247
#
#    total_unique_songs_played_per_month  Percent_Songs_Played_25  \
# 0                                  530                20.177022
# 1                                  885                17.864410
# 2                                  468                 7.021077
# 3                                  828                23.449066
# 4                                  230                14.380372
#
#    Percent_Songs_Played_50  Percent_Songs_Played_100  is_churn
# 0                 3.482550                 74.636630         0
# 1                 8.453724                 67.017440         0
# 2                 3.338308                 87.340876         0
# 3                12.609433                 54.993834         0
# 4                 3.943355                 77.144280         0

# %%
data.isna().sum()
# Out:
# msno                                   0
# Monetary                               0
# Recency                                0
# Frequency                              0
# is_auto_renew                          0
# is_discount                            0
# BestPlan                               0
# active_days_per_month                  0
# total_usage_time_per_month             0
# total_unique_songs_played_per_month    0
# Percent_Songs_Played_25                0
# Percent_Songs_Played_50                0
# Percent_Songs_Played_100               0
# is_churn                               0
# dtype: int64

# %% [markdown]
# ## Creating Cluster Columns for RFM Values

# %% [markdown]
# ### Recency Clustering

# %%
#function for ordering cluster numbers
def order_cluster(cluster_field_name, target_field_name,df,ascending):
    new_cluster_field_name = 'new_' + cluster_field_name
    df_new = df.groupby(cluster_field_name)[target_field_name].mean().reset_index()
    df_new = df_new.sort_values(by=target_field_name,ascending=ascending).reset_index(drop=True)
    df_new['index'] = df_new.index
    df_final = pd.merge(df,df_new[[cluster_field_name,'index']], on=cluster_field_name)
    df_final = df_final.drop([cluster_field_name],axis=1)
    df_final = df_final.rename(columns={"index":cluster_field_name})
    return df_final

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4)
kmeans.fit(data[['Recency']])
data['RecencyCluster'] = kmeans.predict(data[['Recency']])

data = order_cluster('RecencyCluster', 'Recency',data,False)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data.head()
# Out:
#    msno  Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# 0     0      1599      160        395              0            0       395
# 1     7      1788      271        410              0            0       410
# 2    27       894      186        195              0            0       195
# 3   119      1788      169        410              0            0       410
# 4   124       536      178        180              0            0       180
#
#    active_days_per_month  total_usage_time_per_month  \
# 0                     26                  117907.425
# 1                     25                   90177.554
# 2                     23                  230427.576
# 3                     29                  143942.283
# 4                     12                   51199.588
#
#    total_unique_songs_played_per_month  Percent_Songs_Played_25  \
# 0                                  530                20.177022
# 1                                  582                28.582253
# 2                                 1043                 6.345546
# 3                                  258                14.305981
# 4                                  238                24.029165
#
#    Percent_Songs_Played_50  Percent_Songs_Played_100  is_churn  RecencyCluster
# 0                 3.482550                 74.636630         0               1
# 1                 4.374890                 64.295471         0               1
# 2                 0.880708                 91.709406         0               1
# 3                 6.913267                 71.491911         1               1
# 4                 5.266275                 58.750749         0               1

# %%
data['RecencyCluster'].value_counts()
# Out:
# 3    86161
# 2     5092
# 1     3066
# 0     2777
# Name: RecencyCluster, dtype: int64

# %%
data.groupby('RecencyCluster')['Recency'].describe()
# Out:
#                   count        mean        std    min    25%    50%    75%  \
# RecencyCluster
# 0                2777.0  361.447245  50.866337  287.0  324.0  358.0  392.0
# 1                3066.0  210.830724  38.050345  159.0  177.0  202.0  243.0
# 2                5092.0  105.996072  28.175496   61.0   81.0  104.0  130.0
# 3               86161.0   15.550110  11.025457    1.0    6.0   15.0   24.0
#
#                   max
# RecencyCluster
# 0               811.0
# 1               286.0
# 2               158.0
# 3                60.0

# %% [markdown]
# ### Subscription Frequency Clustering

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4)
kmeans.fit(data[['Frequency']])
data['FrequencyCluster'] = kmeans.predict(data[['Frequency']])

data = order_cluster('FrequencyCluster', 'Frequency',data,True)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data.head()
# Out:
#    msno  Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# 0     0      1599      160        395              0            0       395
# 1     7      1788      271        410              0            0       410
# 2   119      1788      169        410              0            0       410
# 3   145      1788      229        410              0            0       410
# 4   160      1788      208        410              0            0       410
#
#    active_days_per_month  total_usage_time_per_month  \
# 0                     26                  117907.425
# 1                     25                   90177.554
# 2                     29                  143942.283
# 3                     31                  191626.664
# 4                      1                     790.830
#
#    total_unique_songs_played_per_month  Percent_Songs_Played_25  \
# 0                                  530                20.177022
# 1                                  582                28.582253
# 2                                  258                14.305981
# 3                                  643                15.398857
# 4                                    5                50.000000
#
#    Percent_Songs_Played_50  Percent_Songs_Played_100  is_churn  \
# 0                 3.482550                 74.636630         0
# 1                 4.374890                 64.295471         0
# 2                 6.913267                 71.491911         1
# 3                 3.980268                 76.323401         0
# 4                 0.000000                 50.000000         0
#
#    RecencyCluster  FrequencyCluster
# 0               1                 2
# 1               1                 2
# 2               1                 2
# 3               1                 2
# 4               1                 2

# %%
data['FrequencyCluster'].value_counts()
# Out:
# 0    82950
# 2     8556
# 1     5119
# 3      471
# Name: FrequencyCluster, dtype: int64

# %%
data.groupby('FrequencyCluster')['Frequency'].describe()
# Out:
#                     count        mean         std    min    25%    50%    75%  \
# FrequencyCluster
# 0                 82950.0   34.787233   13.292939    0.0   30.0   30.0   30.0
# 1                  5119.0  186.223481   23.968760  120.0  180.0  195.0  195.0
# 2                  8556.0  406.243922   19.963473  300.0  410.0  410.0  410.0
# 3                   471.0  712.350318  151.696275  560.0  600.0  630.0  820.0
#
#                      max
# FrequencyCluster
# 0                  107.0
# 1                  292.0
# 2                  540.0
# 3                 1680.0

# %% [markdown]
# ### Monetary Clustering

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4)
kmeans.fit(data[['Monetary']])
data['MonetaryCluster'] = kmeans.predict(data[['Monetary']])

data = order_cluster('MonetaryCluster', 'Monetary',data,True)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data.head()
# Out:
#    msno  Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# 0     0      1599      160        395              0            0       395
# 1     7      1788      271        410              0            0       410
# 2   119      1788      169        410              0            0       410
# 3   145      1788      229        410              0            0       410
# 4   160      1788      208        410              0            0       410
#
#    active_days_per_month  total_usage_time_per_month  \
# 0                     26                  117907.425
# 1                     25                   90177.554
# 2                     29                  143942.283
# 3                     31                  191626.664
# 4                      1                     790.830
#
#    total_unique_songs_played_per_month  Percent_Songs_Played_25  \
# 0                                  530                20.177022
# 1                                  582                28.582253
# 2                                  258                14.305981
# 3                                  643                15.398857
# 4                                    5                50.000000
#
#    Percent_Songs_Played_50  Percent_Songs_Played_100  is_churn  \
# 0                 3.482550                 74.636630         0
# 1                 4.374890                 64.295471         0
# 2                 6.913267                 71.491911         1
# 3                 3.980268                 76.323401         0
# 4                 0.000000                 50.000000         0
#
#    RecencyCluster  FrequencyCluster  MonetaryCluster
# 0               1                 2                2
# 1               1                 2                2
# 2               1                 2                2
# 3               1                 2                2
# 4               1                 2                2

# %%
data['MonetaryCluster'].value_counts()
# Out:
# 0    81734
# 2     8523
# 1     6601
# 3      238
# Name: MonetaryCluster, dtype: int64

# %%
data.groupby('MonetaryCluster')['Monetary'].describe()
# Out:
#                    count         mean         std     min     25%     50%  \
# MonetaryCluster
# 0                81734.0   146.865931   62.089107     0.0    99.0   149.0
# 1                 6601.0   715.024390  216.084533   446.0   536.0   699.0
# 2                 8523.0  1765.667371  155.873563  1251.0  1788.0  1788.0
# 3                  238.0  3541.789916  812.036201  2671.0  2991.5  3387.0
#
#                     75%     max
# MonetaryCluster
# 0                 149.0   427.0
# 1                 894.0  1211.0
# 2                1788.0  2651.0
# 3                3576.0  8850.0

# %% [markdown]
# ### Songs Played Frequency Clustering

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4)
kmeans.fit(data[['total_usage_time_per_month']])
data['SongsPlayedFrequencyCluster'] = kmeans.predict(data[['total_usage_time_per_month']])

data = order_cluster('SongsPlayedFrequencyCluster', 'total_usage_time_per_month',data,True)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data.head()
# Out:
#    msno  Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# 0     0      1599      160        395              0            0       395
# 1     7      1788      271        410              0            0       410
# 2   160      1788      208        410              0            0       410
# 3   187      1788      219        410              0            0       410
# 4   300      1788      166        410              0            0       410
#
#    active_days_per_month  total_usage_time_per_month  \
# 0                     26                  117907.425
# 1                     25                   90177.554
# 2                      1                     790.830
# 3                     12                   48210.151
# 4                     28                   88209.978
#
#    total_unique_songs_played_per_month  Percent_Songs_Played_25  \
# 0                                  530                20.177022
# 1                                  582                28.582253
# 2                                    5                50.000000
# 3                                  364                38.219879
# 4                                  461                17.378106
#
#    Percent_Songs_Played_50  Percent_Songs_Played_100  is_churn  \
# 0                 3.482550                 74.636630         0
# 1                 4.374890                 64.295471         0
# 2                 0.000000                 50.000000         0
# 3                32.594632                 23.739586         1
# 4                 2.824991                 77.837649         0
#
#    RecencyCluster  FrequencyCluster  MonetaryCluster  \
# 0               1                 2                2
# 1               1                 2                2
# 2               1                 2                2
# 3               1                 2                2
# 4               1                 2                2
#
#    SongsPlayedFrequencyCluster
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0

# %%
data['SongsPlayedFrequencyCluster'].value_counts()
# Out:
# 0    62463
# 1    26163
# 2     6880
# 3     1590
# Name: SongsPlayedFrequencyCluster, dtype: int64

# %%
data.groupby('SongsPlayedFrequencyCluster')['total_usage_time_per_month'].describe()
# Out:
#                                count          mean            std         min  \
# SongsPlayedFrequencyCluster
# 0                            62463.0  4.179844e+04   35301.474116       0.131
# 1                            26163.0  1.961766e+05   58379.002143  118790.527
# 2                             6880.0  4.789176e+05  113476.531659  337165.287
# 3                             1590.0  1.058967e+06  305011.488944  768545.191
#
#                                       25%          50%           75%  \
# SongsPlayedFrequencyCluster
# 0                              9212.05050   34010.8770  6.972453e+04
# 1                            146778.98900  182905.1000  2.371880e+05
# 2                            382567.65325  449000.3980  5.545878e+05
# 3                            852823.62125  962767.2725  1.161660e+06
#
#                                      max
# SongsPlayedFrequencyCluster
# 0                             118782.059
# 1                             337135.926
# 2                             768355.858
# 3                            3028970.526

# %% [markdown]
# ## Calculating the Overall Score and Creating Segment Column

# %% [markdown]
# ### Overall Score

# %%
data['OverallScore'] = data['FrequencyCluster']+data['SongsPlayedFrequencyCluster']+data['RecencyCluster']+data['MonetaryCluster']

# %%
data.head()
# Out:
#    msno  Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# 0     0      1599      160        395              0            0       395
# 1     7      1788      271        410              0            0       410
# 2   160      1788      208        410              0            0       410
# 3   187      1788      219        410              0            0       410
# 4   300      1788      166        410              0            0       410
#
#    active_days_per_month  total_usage_time_per_month  \
# 0                     26                  117907.425
# 1                     25                   90177.554
# 2                      1                     790.830
# 3                     12                   48210.151
# 4                     28                   88209.978
#
#    total_unique_songs_played_per_month  Percent_Songs_Played_25  \
# 0                                  530                20.177022
# 1                                  582                28.582253
# 2                                    5                50.000000
# 3                                  364                38.219879
# 4                                  461                17.378106
#
#    Percent_Songs_Played_50  Percent_Songs_Played_100  is_churn  \
# 0                 3.482550                 74.636630         0
# 1                 4.374890                 64.295471         0
# 2                 0.000000                 50.000000         0
# 3                32.594632                 23.739586         1
# 4                 2.824991                 77.837649         0
#
#    RecencyCluster  FrequencyCluster  MonetaryCluster  \
# 0               1                 2                2
# 1               1                 2                2
# 2               1                 2                2
# 3               1                 2                2
# 4               1                 2                2
#
#    SongsPlayedFrequencyCluster  OverallScore
# 0                            0             5
# 1                            0             5
# 2                            0             5
# 3                            0             5
# 4                            0             5

# %%
data['OverallScore'].value_counts()
# Out:
# 3     53135
# 4     26056
# 5     10148
# 6      4436
# 7      1960
# 8       729
# 9       286
# 2       195
# 10       68
# 0        37
# 1        26
# 11       16
# 12        4
# Name: OverallScore, dtype: int64

# %% [markdown]
# ### Segmentation

# %%
data.groupby('OverallScore')['Recency','Frequency','Monetary','total_usage_time_per_month'].mean()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_18656/3429112469.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('OverallScore')['Recency','Frequency','Monetary','total_usage_time_per_month'].mean()
#                  Recency   Frequency     Monetary  total_usage_time_per_month
# OverallScore
# 0             436.081081   43.378378   206.459459                3.811301e+04
# 1             353.192308   51.000000   202.653846                1.228563e+05
# 2             161.615385   98.876923   396.343590                4.682204e+04
# 3              16.908723   35.517117   153.933358                4.206817e+04
# 4              43.964231   69.999616   299.221715                1.729352e+05
# 5              76.886973  144.109283   611.009361                3.188393e+05
# 6              96.522317  253.864968  1071.383003                4.360633e+05
# 7              83.029082  391.400510  1658.008163                2.173477e+05
# 8              60.012346  457.847737  1881.611797                3.037016e+05
# 9              40.618881  593.045455  2534.013986                3.547103e+05
# 10             27.720588  630.058824  2725.338235                5.033123e+05
# 11             25.687500  765.500000  3246.875000                6.290858e+05
# 12             15.000000  677.500000  3252.500000                1.002471e+06

# %%
data['Segment'] = 'Low-Value'
data.loc[data['OverallScore']>3,'Segment'] = 'Mid-Value' 
data.loc[data['OverallScore']>5,'Segment'] = 'High-Value'

# %%
data.head()
# Out:
#    msno  Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# 0     0      1599      160        395              0            0       395
# 1     7      1788      271        410              0            0       410
# 2   160      1788      208        410              0            0       410
# 3   187      1788      219        410              0            0       410
# 4   300      1788      166        410              0            0       410
#
#    active_days_per_month  total_usage_time_per_month  \
# 0                     26                  117907.425
# 1                     25                   90177.554
# 2                      1                     790.830
# 3                     12                   48210.151
# 4                     28                   88209.978
#
#    total_unique_songs_played_per_month  Percent_Songs_Played_25  \
# 0                                  530                20.177022
# 1                                  582                28.582253
# 2                                    5                50.000000
# 3                                  364                38.219879
# 4                                  461                17.378106
#
#    Percent_Songs_Played_50  Percent_Songs_Played_100  is_churn  \
# 0                 3.482550                 74.636630         0
# 1                 4.374890                 64.295471         0
# 2                 0.000000                 50.000000         0
# 3                32.594632                 23.739586         1
# 4                 2.824991                 77.837649         0
#
#    RecencyCluster  FrequencyCluster  MonetaryCluster  \
# 0               1                 2                2
# 1               1                 2                2
# 2               1                 2                2
# 3               1                 2                2
# 4               1                 2                2
#
#    SongsPlayedFrequencyCluster  OverallScore    Segment
# 0                            0             5  Mid-Value
# 1                            0             5  Mid-Value
# 2                            0             5  Mid-Value
# 3                            0             5  Mid-Value
# 4                            0             5  Mid-Value

# %%
data['BestPlan'].value_counts()
# Out:
# 30     82032
# 410     6457
# 195     2181
# 180     1782
# 90      1306
# 395      812
# 7        360
# 100      344
# 415      282
# 365      272
# 200      238
# 360      209
# 120      186
# 240      139
# 60       136
# 450      135
# 400      126
# 270       60
# 1         25
# 10         6
# 14         4
# 80         2
# 45         1
# 0          1
# Name: BestPlan, dtype: int64

# %%
data['Plan'] = 'Yearly Plan'
data.loc[(data['BestPlan']<7) & (data['BestPlan']>=0),'Plan'] = 'Daily'
data.loc[(data['BestPlan']<30) & (data['BestPlan']>=7),'Plan'] = 'Weekly'
data.loc[(data['BestPlan']<90) & (data['BestPlan']>=30), 'Plan'] = 'Monthly'
data.loc[(data['BestPlan']<180) & (data['BestPlan']>=90), 'Plan'] = 'Three Months'
data.loc[(data['BestPlan']<300) & (data['BestPlan']>=180), 'Plan'] = 'Six Months'
data.loc[data['BestPlan']>=300,'Plan'] = 'Yearly'

# %%
data['Plan'].value_counts()
# Out:
# Monthly         82171
# Yearly           8293
# Six Months       4400
# Three Months     1836
# Weekly            370
# Daily              26
# Name: Plan, dtype: int64

# %%
data['Segment'].value_counts()
# Out:
# Low-Value     53393
# Mid-Value     36204
# High-Value     7499
# Name: Segment, dtype: int64

# %%
data.head()
# Out:
#    msno  Monetary  Recency  Frequency  is_auto_renew  is_discount  BestPlan  \
# 0     0      1599      160        395              0            0       395
# 1     7      1788      271        410              0            0       410
# 2   160      1788      208        410              0            0       410
# 3   187      1788      219        410              0            0       410
# 4   300      1788      166        410              0            0       410
#
#    active_days_per_month  total_usage_time_per_month  \
# 0                     26                  117907.425
# 1                     25                   90177.554
# 2                      1                     790.830
# 3                     12                   48210.151
# 4                     28                   88209.978
#
#    total_unique_songs_played_per_month  ...  Percent_Songs_Played_50  \
# 0                                  530  ...                 3.482550
# 1                                  582  ...                 4.374890
# 2                                    5  ...                 0.000000
# 3                                  364  ...                32.594632
# 4                                  461  ...                 2.824991
#
#    Percent_Songs_Played_100  is_churn  RecencyCluster  FrequencyCluster  \
# 0                 74.636630         0               1                 2
# 1                 64.295471         0               1                 2
# 2                 50.000000         0               1                 2
# 3                 23.739586         1               1                 2
# 4                 77.837649         0               1                 2
#
#    MonetaryCluster  SongsPlayedFrequencyCluster  OverallScore    Segment  \
# 0                2                            0             5  Mid-Value
# 1                2                            0             5  Mid-Value
# 2                2                            0             5  Mid-Value
# 3                2                            0             5  Mid-Value
# 4                2                            0             5  Mid-Value
#
#      Plan
# 0  Yearly
# 1  Yearly
# 2  Yearly
# 3  Yearly
# 4  Yearly
#
# [5 rows x 21 columns]

# %%
data.to_csv('TransformedDataset/transformed_user_summary_segemented.csv',index=False)
